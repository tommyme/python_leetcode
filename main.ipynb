# %%
import requests as r

def simple(ddict):
    return {k:v for k, v in ddict.items() if k not in ['id', 'name', 'slug']}
url = "https://leetcode-cn.com/_next/data/b9wDieNID7YfdtzWasKYh/problemset/all.json"
resp = r.get(url).json()
[i for i in resp['pageProps']['topicTags']]
# Out:
# [{'id': 'VG9waWNUYWdOb2RlOjU0MA==',
#   'name': 'Array',
#   'slug': 'array',
#   'translatedName': '数组',
#   'questionCount': 1231},
#  {'id': 'VG9waWNUYWdOb2RlOjU1Nw==',
#   'name': 'String',
#   'slug': 'string',
#   'translatedName': '字符串',
#   'questionCount': 594},
#  {'id': 'VG9waWNUYWdOb2RlOjU0MQ==',
#   'name': 'Hash Table',
#   'slug': 'hash-table',
#   'translatedName': '哈希表',
#   'questionCount': 439},
#  {'id': 'VG9waWNUYWdOb2RlOjU2Mg==',
#   'name': 'Dynamic Programming',
#   'slug': 'dynamic-programming',
#   'translatedName': '动态规划',
#   'questionCount': 429},
#  {'id': 'VG9waWNUYWdOb2RlOjU1NQ==',
#   'name': 'Math',
#   'slug': 'math',
#   'translatedName': '数学',
#   'questionCount': 416},
#  {'id': 'VG9waWNUYWdOb2RlOjQ1Ng==',
#   'name': 'Depth-First Search',
#   'slug': 'depth-first-search',
#   'translatedName': '深度优先搜索',
#   'questionCount': 294},
#  {'id': 'VG9waWNUYWdOb2RlOjQyOTU5',
#   'name': 'Sorting',
#   'slug': 'sorting',
#   'translatedName': '排序',
# ...

# %%
a = {"a":1, "b":2}
b = {"b":2, "a":1}
a == b
# Out:
# True
